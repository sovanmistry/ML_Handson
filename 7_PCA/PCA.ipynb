# %% [markdown]
# ## PCA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.decomposition import PCA

# %%
from sklearn import datasets

# %%
dataset = datasets.load_iris()

# %%
X = dataset['data']
y = dataset['target']

# %%
from sklearn.model_selection import train_test_split

# %%
X_test, X_train, y_test, y_train = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
# array([[6.1, 2.8, 4.7, 1.2],
#        [5.7, 3.8, 1.7, 0.3],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.9, 4.5, 1.5],
#        [6.8, 2.8, 4.8, 1.4],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.9, 3.1, 5.1, 2.3],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.8, 2.7, 3.9, 1.2],
#        [6.5, 3.2, 5.1, 2. ],
#        [4.8, 3. , 1.4, 0.1],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.1, 3.8, 1.5, 0.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [6.5, 3. , 5.8, 2.2],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.4, 2.8, 5.6, 2.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [6.1, 3. , 4.9, 1.8],
#        [5. , 3.4, 1.6, 0.4],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.7, 3. , 5.2, 2.3],
#        [6.7, 2.5, 5.8, 1.8],
#        [6.8, 3.2, 5.9, 2.3],
#        [4.8, 3. , 1.4, 0.3],
#        [4.8, 3.1, 1.6, 0.2],
#        [4.6, 3.6, 1. , 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [6.7, 3.1, 4.4, 1.4],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.4, 3.2, 1.3, 0.2],
#        [6.3, 2.5, 5. , 1.9],
#        [6.4, 3.2, 4.5, 1.5],
#        [5.2, 3.5, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.8, 2.7, 5.1, 1.9],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.4, 3.7, 1.5, 0.2],
#        [5.5, 2.4, 3.7, 1. ],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.6, 3. , 4.4, 1.4],
#        [7.2, 3.6, 6.1, 2.5]])

# %%
pca = PCA(n_components=3)

# %%
X_train = pca.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.02799542, -0.31467953,  0.15777091],
#        [-2.11536297,  0.67467328,  0.20846312],
#        [ 3.89502341,  0.16130146,  0.50806456],
#        [ 0.92012482, -0.26216508, -0.08405848],
#        [ 1.43241848,  0.08771424,  0.52011321],
#        [-2.31238038,  0.21086871,  0.19339783],
#        [-0.06343796, -0.36810704, -0.13518426],
#        [ 2.01955863,  0.34915835, -0.05540831],
#        [ 1.065967  , -0.69746746,  0.42051324],
#        [ 0.24875725, -0.45321761,  0.11484634],
#        [ 1.75895639,  0.18798943, -0.23108758],
#        [-2.67489169, -0.44976269,  0.15911579],
#        [-2.53198124,  0.37689958,  0.33428697],
#        [-2.56496231, -0.32613664,  0.16074204],
#        [-2.49739987,  0.34844574, -0.17143788],
#        [ 1.18995309,  0.20368068, -0.16783406],
#        [ 2.45236354, -0.07194011, -0.31883064],
#        [ 0.16363931, -0.73112098,  0.13406626],
#        [ 0.75266083, -0.52126707, -0.13593419],
#        [ 2.26765321, -0.2598825 , -0.25427498],
#        [-2.52407281, -0.37941911, -0.09047664],
#        [ 1.39598989, -0.17992326, -0.27111554],
#        [-2.367401  , -0.04118544, -0.09130884],
#        [ 2.23124778, -0.2609031 , -0.20485454],
#        [ 3.29873211,  1.30051597,  0.22681727],
#        [ 2.04562707,  0.13659193, -0.15179073],
#        [ 2.43099962, -0.35306151,  0.278007  ],
#        [ 2.65820304,  0.25045762, -0.2837164 ],
#        [-2.60208083, -0.44772149,  0.06027491],
#        [-2.47813219, -0.39924109,  0.03003944],
#        [-3.11582877, -0.03331004, -0.28827245],
#        [-2.31485692,  1.18011465, -0.13025679],
#        [ 1.02260096,  0.32506094,  0.34807731],
#        [-2.51050874, -0.16184604, -0.1280843 ],
#        [-2.88623752, -0.5129022 , -0.25347914],
#        [ 1.64222626, -0.47075701,  0.06514591],
#        [ 1.02834202,  0.21246878,  0.02905046],
#        [-2.4662803 ,  0.1693398 ,  0.10391446],
#        [-2.6329425 ,  0.14466741, -0.07093579],
#        [-2.56743885,  0.6431093 , -0.16291257],
#        [ 1.53047282, -0.6238575 , -0.39278475],
#        [ 0.90256932,  0.13451393, -0.39701848],
#        [ 1.31572578,  0.28163553,  0.25823487],
#        [-2.53748757,  0.63615781, -0.04319373],
#        [-2.4175678 ,  0.44622257,  0.13411497],
#        [-0.06826864, -0.84095229,  0.19533445],
#        [ 1.54980111, -0.25225969,  0.09122993],
#        [ 2.0040818 , -0.0117545 , -0.20124296],
#        [ 0.99824471,  0.18661956,  0.33297706],
#        [ 2.99958518,  0.77663368, -0.34910426]])

# %%
# give corordinates of eigen vector
pca.components_
# Out:
# array([[ 0.35148439, -0.10792186,  0.8557313 ,  0.36405431],
#        [ 0.59309703,  0.79131683, -0.14815339,  0.01020597],
#        [ 0.67808168, -0.52707912, -0.13474002, -0.49420438]])

# %%
# how many variance getting captured with the help of this PCA model
pca.explained_variance_ratio_
# Out:
# array([0.93858749, 0.04474854, 0.01156705])
